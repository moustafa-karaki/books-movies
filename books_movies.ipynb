# %%
import pandas as pd
import numpy as np
import os

# %%
movies = pd.read_csv('movies.csv')

# %%
movies.head()
# Out:
#                                               poster  \
# 0  https://m.media-amazon.com/images/S/sash/4Fyxw...
# 1  https://m.media-amazon.com/images/S/sash/4Fyxw...
# 2  https://m.media-amazon.com/images/S/sash/4Fyxw...
# 3  https://m.media-amazon.com/images/S/sash/4Fyxw...
# 4  https://m.media-amazon.com/images/S/sash/4Fyxw...
#
#                       title certificate  runtime                      genre  \
# 0  The Shawshank Redemption          15  142 min                      Drama
# 1           The Dark Knight         12A  152 min       Action, Crime, Drama
# 2                 Inception         12A  148 min  Action, Adventure, Sci-Fi
# 3                Fight Club          18  139 min                      Drama
# 4              Pulp Fiction          18  154 min               Crime, Drama
#
#    rating                                              about  \
# 0     9.3  Two imprisoned men bond over a number of years...
# 1     9.0  When the menace known as the Joker wreaks havo...
# 2     8.8  A thief who steals corporate secrets through t...
# 3     8.8  An insomniac office worker and a devil-may-car...
# 4     8.9  The lives of two mob hitmen, a boxer, a gangst...
#
#             director                                              stars  \
# 0     Frank Darabont  ('Tim Robbins',), ('Morgan Freeman',), ('Bob G...
# 1  Christopher Nolan  ('Christian Bale',), ('Heath Ledger',), ('Aaro...
# 2  Christopher Nolan  ('Leonardo DiCaprio',), ('Joseph Gordon-Levitt...
# 3      David Fincher  ('Brad Pitt',), ('Edward Norton',), ('Meat Loa...
# 4  Quentin Tarantino  ('John Travolta',), ('Uma Thurman',), ('Samuel...
#
#        votes gross_earn
# 0  26,26,905    $28.34M
# 1  25,98,173   $534.86M
# 2  23,04,062   $292.58M
# 3  20,71,088    $37.03M
# 4  20,11,013   $107.93M

# %%
movies.loc[movies["title"].str.startswith('The Hunger Games')]
# Out:
#                                                 poster  \
# 46   https://m.media-amazon.com/images/S/sash/4Fyxw...
# 113  https://m.media-amazon.com/images/S/sash/4Fyxw...
# 301  https://m.media-amazon.com/images/S/sash/4Fyxw...
# 769  https://m.media-amazon.com/images/S/sash/4Fyxw...
#
#                                      title certificate  runtime  \
# 46                        The Hunger Games         12A  142 min
# 113        The Hunger Games: Catching Fire         12A  146 min
# 301  The Hunger Games: Mockingjay - Part 1         12A  123 min
# 769  The Hunger Games: Mockingjay - Part 2         12A  137 min
#
#                          genre  rating  \
# 46   Action, Adventure, Sci-Fi     7.2
# 113  Action, Adventure, Sci-Fi     7.5
# 301  Action, Adventure, Sci-Fi     6.6
# 769  Action, Adventure, Sci-Fi     6.5
#
#                                                  about          director  \
# 46   Katniss Everdeen voluntarily takes her younger...         Gary Ross
# 113  Katniss Everdeen and Peeta Mellark become targ...  Francis Lawrence
# 301  Katniss Everdeen is in District 13 after she s...  Francis Lawrence
# 769  Katniss and a team of rebels from District 13 ...  Francis Lawrence
#
#                                                  stars     votes gross_earn
# 46   ('Jennifer Lawrence',), ('Josh Hutcherson',), ...  9,07,228   $408.01M
# 113  ('Jennifer Lawrence',), ('Josh Hutcherson',), ...  6,57,641   $424.67M
# 301  ('Jennifer Lawrence',), ('Josh Hutcherson',), ...  4,50,373   $337.14M
# 769  ('Jennifer Lawrence',), ('Josh Hutcherson',), ...  3,22,089   $281.72M

# %%
books = pd.read_csv('books.csv', on_bad_lines='skip')

# %%
books
# Out:
#        bookID                                              title  \
# 0           1  Harry Potter and the Half-Blood Prince (Harry ...
# 1           2  Harry Potter and the Order of the Phoenix (Har...
# 2           4  Harry Potter and the Chamber of Secrets (Harry...
# 3           5  Harry Potter and the Prisoner of Azkaban (Harr...
# 4           8  Harry Potter Boxed Set  Books 1-5 (Harry Potte...
# ...       ...                                                ...
# 11118   45631   Expelled from Eden: A William T. Vollmann Reader
# 11119   45633                        You Bright and Risen Angels
# 11120   45634                    The Ice-Shirt (Seven Dreams #1)
# 11121   45639                                        Poor People
# 11122   45641                        Las aventuras de Tom Sawyer
#
#                                                  authors  average_rating  \
# 0                             J.K. Rowling/Mary GrandPré            4.57
# 1                             J.K. Rowling/Mary GrandPré            4.49
# 2                                           J.K. Rowling            4.42
# 3                             J.K. Rowling/Mary GrandPré            4.56
# 4                             J.K. Rowling/Mary GrandPré            4.78
# ...                                                  ...             ...
# 11118  William T. Vollmann/Larry McCaffery/Michael He...            4.06
# 11119                                William T. Vollmann            4.08
# 11120                                William T. Vollmann            3.96
# 11121                                William T. Vollmann            3.72
# 11122                                         Mark Twain            3.91
#
#              isbn         isbn13 language_code    num_pages  ratings_count  \
# 0      0439785960  9780439785969           eng          652        2095690
# 1      0439358078  9780439358071           eng          870        2153167
# 2      0439554896  9780439554893           eng          352           6333
# 3      043965548X  9780439655484           eng          435        2339585
# 4      0439682584  9780439682589           eng         2690          41428
# ...           ...            ...           ...          ...            ...
# 11118  1560254416  9781560254416           eng          512            156
# 11119  0140110879  9780140110876           eng          635            783
# 11120  0140131965  9780140131963           eng          415            820
# 11121  0060878827  9780060878825           eng          434            769
# 11122  8497646983  9788497646987           spa          272            113
#
#        text_reviews_count publication_date        publisher
# 0                   27591        9/16/2006  Scholastic Inc.
# 1                   29221         9/1/2004  Scholastic Inc.
# 2                     244        11/1/2003       Scholastic
# 3                   36325         5/1/2004  Scholastic Inc.
# 4                     164        9/13/2004       Scholastic
# ...                   ...              ...              ...
# 11118                  20       12/21/2004    Da Capo Press
# 11119                  56        12/1/1988    Penguin Books
# 11120                  95         8/1/1993    Penguin Books
# 11121                 139        2/27/2007             Ecco
# 11122                  12        5/28/2006    Edimat Libros
#
# [11123 rows x 12 columns]

# %%
books.loc[books["title"].str.contains('Games')]
# Out:
#        bookID                                              title  \
# 3824    13674                  The Life and Games of Mikhail Tal
# 4299    15464                           Faun & Games (Xanth #21)
# 5023    18184  The Complete Theory Fun Factory: Music Theory ...
# 5147    18630                  The Player of Games (Culture  #2)
# 7764    29967                    Floor Games (Sandplay Classics)
# 8508    32682                      Patriot Games (Jack Ryan  #1)
# 9949    40090                        Sacred Games (Sacred Games)
# 10333   41862                  Evolution and the Theory of Games
#
#                                         authors  average_rating        isbn  \
# 3824   Mikhail Tal/Iakov Damsky/Kenneth P. Neat            4.52  1857442024
# 4299                              Piers Anthony            3.76  0812555112
# 5023            Ian        Martin/Katie Elliott            5.00  0851621813
# 5147                              Iain M. Banks            4.27  0061053562
# 7764               H.G. Wells/Barbara A. Turner            3.40  0972851720
# 8508                                 Tom Clancy            4.14  0425134350
# 9949                             Vikram Chandra            3.93  0061130354
# 10333                        John Maynard Smith            4.00  0521288843
#
#               isbn13 language_code    num_pages  ratings_count  \
# 3824   9781857442021           eng          496            442
# 4299   9780812555110           eng          352           4039
# 5023   9780851621814           eng           96              1
# 5147   9780061053566           eng          293          46139
# 7764   9780972851725           eng          110             46
# 8508   9780425134351           eng          503         170797
# 9949   9780061130359           eng          916           5983
# 10333  9780521288842           eng          234             86
#
#        text_reviews_count publication_date                   publisher
# 3824                   24         7/1/1997              Everyman Chess
# 4299                   38       10/15/1997                 Tor Fantasy
# 5023                    0         6/1/2004         Boosey & Hawkes Inc
# 5147                 1648         2/1/1997                 HarperPrism
# 7764                    3         9/1/2004               Temenos Press
# 8508                  984         5/1/1992                     Berkley
# 9949                  724         1/9/2007               HarperCollins
# 10333                   5       10/21/1982  Cambridge University Press

# %% [markdown]
# Jrassic park,
# harry potter,
# dune, the hunger games

# %%
movies = movies.drop(columns= ["poster","certificate","runtime","genre","about","director","stars","votes", "gross_earn"])

# %%
movies.head()
# Out:
#                       title  rating
# 0  The Shawshank Redemption     9.3
# 1           The Dark Knight     9.0
# 2                 Inception     8.8
# 3                Fight Club     8.8
# 4              Pulp Fiction     8.9

# %%
books = books.drop(columns= ["bookID", "authors" ,"isbn"	,"isbn13","ratings_count",	"text_reviews_count"	,"publication_date",	"publisher"])

# %%
books.head()
# Out:
#                                                title  average_rating  \
# 0  Harry Potter and the Half-Blood Prince (Harry ...            4.57
# 1  Harry Potter and the Order of the Phoenix (Har...            4.49
# 2  Harry Potter and the Chamber of Secrets (Harry...            4.42
# 3  Harry Potter and the Prisoner of Azkaban (Harr...            4.56
# 4  Harry Potter Boxed Set  Books 1-5 (Harry Potte...            4.78
#
#   language_code    num_pages
# 0           eng          652
# 1           eng          870
# 2           eng          352
# 3           eng          435
# 4           eng         2690
