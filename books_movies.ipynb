# %%
import pandas as pd
import numpy as np
import os 
from matplotlib import pyplot as plt

# %%
movies = pd.read_csv('movies.csv')

# %%
movies.head()
# Out:
#                                                          poster  \
# 0  https://m.media-amazon.com/images/S/sash/4FyxwxECzL-U1J8.png
# 1  https://m.media-amazon.com/images/S/sash/4FyxwxECzL-U1J8.png
# 2  https://m.media-amazon.com/images/S/sash/4FyxwxECzL-U1J8.png
# 3  https://m.media-amazon.com/images/S/sash/4FyxwxECzL-U1J8.png
# 4  https://m.media-amazon.com/images/S/sash/4FyxwxECzL-U1J8.png
#
#                       title certificate  runtime                      genre  \
# 0  The Shawshank Redemption          15  142 min                      Drama
# 1           The Dark Knight         12A  152 min       Action, Crime, Drama
# 2                 Inception         12A  148 min  Action, Adventure, Sci-Fi
# 3                Fight Club          18  139 min                      Drama
# 4              Pulp Fiction          18  154 min               Crime, Drama
#
#    rating  \
# 0     9.3
# 1     9.0
# 2     8.8
# 3     8.8
# 4     8.9
#
#                                                                                                                                                                                                                           about  \
# 0                                                                                                        Two imprisoned men bond over a number of years, finding solace and eventual redemption through acts of common decency.
# 1                                 When the menace known as the Joker wreaks havoc and chaos on the people of Gotham, Batman must accept one of the greatest psychological and physical tests of his ability to fight injustice.
# 2  A thief who steals corporate secrets through the use of dream-sharing technology is given the inverse task of planting an idea into the mind of a C.E.O., but his tragic past may doom the project and his team to disaster.
# 3                                                                                                        An insomniac office worker and a devil-may-care soap maker form an underground fight club that evolves into much more.
# 4                                                                               The lives of two mob hitmen, a boxer, a gangster and his wife, and a pair of diner bandits intertwine in four tales of violence and redemption.
#
#             director  \
# 0     Frank Darabont
# 1  Christopher Nolan
# 2  Christopher Nolan
# 3      David Fincher
# 4  Quentin Tarantino
#
#                                                                                     stars  \
# 0             ('Tim Robbins',), ('Morgan Freeman',), ('Bob Gunton',), ('William Sadler',)
# 1          ('Christian Bale',), ('Heath Ledger',), ('Aaron Eckhart',), ('Michael Caine',)
# 2  ('Leonardo DiCaprio',), ('Joseph Gordon-Levitt',), ('Elliot Page',), ('Ken Watanabe',)
# 3                   ('Brad Pitt',), ('Edward Norton',), ('Meat Loaf',), ('Zach Grenier',)
# 4         ('John Travolta',), ('Uma Thurman',), ('Samuel L. Jackson',), ('Bruce Willis',)
#
#        votes gross_earn
# 0  26,26,905    $28.34M
# 1  25,98,173   $534.86M
# 2  23,04,062   $292.58M
# 3  20,71,088    $37.03M
# 4  20,11,013   $107.93M

# %%
movies.loc[movies["title"].str.contains('Narnia')]
# Out:
#                                                             poster  \
# 333   https://m.media-amazon.com/images/S/sash/4FyxwxECzL-U1J8.png
# 848   https://m.media-amazon.com/images/S/sash/4FyxwxECzL-U1J8.png
# 1228  https://m.media-amazon.com/images/S/sash/4FyxwxECzL-U1J8.png
#
#                                                                title  \
# 333   The Chronicles of Narnia: The Lion, the Witch and the Wardrobe
# 848                         The Chronicles of Narnia: Prince Caspian
# 1228        The Chronicles of Narnia: The Voyage of the Dawn Treader
#
#      certificate  runtime                       genre  rating  \
# 333           PG  143 min  Adventure, Family, Fantasy     6.9
# 848           PG  150 min   Action, Adventure, Family     6.5
# 1228          PG  113 min  Adventure, Family, Fantasy     6.3
#
#                                                                                                                                                                                                                                                                                                         about  \
# 333                                                                                                                                                                     Four kids travel through a wardrobe to the land of Narnia and learn of their destiny to free it with the guidance of a mystical lion.
# 848                                                                                                                              The Pevensie siblings return to Narnia, where they are enlisted to once again help ward off an evil king and restore the rightful heir to the land's throne, Prince Caspian.
# 1228  Lucy and Edmund Pevensie return to Narnia with their cousin Eustace where they meet up with Prince Caspian for a trip across the sea aboard the royal ship The Dawn Treader. Along the way they encounter dragons, dwarves, merfolk, and a band of lost warriors before reaching the edge of the world.
#
#             director  \
# 333   Andrew Adamson
# 848   Andrew Adamson
# 1228   Michael Apted
#
#                                                                                    stars  \
# 333   ('Tilda Swinton',), ('Georgie Henley',), ('William Moseley',), ('Skandar Keynes',)
# 848      ('Ben Barnes',), ('Skandar Keynes',), ('Georgie Henley',), ('William Moseley',)
# 1228        ('Ben Barnes',), ('Skandar Keynes',), ('Georgie Henley',), ('Will Poulter',)
#
#          votes gross_earn
# 333   3,94,549   $291.71M
# 848   2,09,477   $141.62M
# 1228  1,53,710   $104.39M

# %%
books = pd.read_csv('books.csv', on_bad_lines='skip')

# %%
books
# Out:
#        bookID                                                         title  \
# 0           1     Harry Potter and the Half-Blood Prince (Harry Potter  #6)
# 1           2  Harry Potter and the Order of the Phoenix (Harry Potter  #5)
# 2           4    Harry Potter and the Chamber of Secrets (Harry Potter  #2)
# 3           5   Harry Potter and the Prisoner of Azkaban (Harry Potter  #3)
# 4           8        Harry Potter Boxed Set  Books 1-5 (Harry Potter  #1-5)
# ...       ...                                                           ...
# 11118   45631              Expelled from Eden: A William T. Vollmann Reader
# 11119   45633                                   You Bright and Risen Angels
# 11120   45634                               The Ice-Shirt (Seven Dreams #1)
# 11121   45639                                                   Poor People
# 11122   45641                                   Las aventuras de Tom Sawyer
#
#                                                       authors  average_rating  \
# 0                                  J.K. Rowling/Mary GrandPré            4.57
# 1                                  J.K. Rowling/Mary GrandPré            4.49
# 2                                                J.K. Rowling            4.42
# 3                                  J.K. Rowling/Mary GrandPré            4.56
# 4                                  J.K. Rowling/Mary GrandPré            4.78
# ...                                                       ...             ...
# 11118  William T. Vollmann/Larry McCaffery/Michael Hemmingson            4.06
# 11119                                     William T. Vollmann            4.08
# 11120                                     William T. Vollmann            3.96
# 11121                                     William T. Vollmann            3.72
# 11122                                              Mark Twain            3.91
#
#              isbn         isbn13 language_code    num_pages  ratings_count  \
# 0      0439785960  9780439785969           eng          652        2095690
# 1      0439358078  9780439358071           eng          870        2153167
# 2      0439554896  9780439554893           eng          352           6333
# 3      043965548X  9780439655484           eng          435        2339585
# 4      0439682584  9780439682589           eng         2690          41428
# ...           ...            ...           ...          ...            ...
# 11118  1560254416  9781560254416           eng          512            156
# 11119  0140110879  9780140110876           eng          635            783
# 11120  0140131965  9780140131963           eng          415            820
# 11121  0060878827  9780060878825           eng          434            769
# 11122  8497646983  9788497646987           spa          272            113
#
#        text_reviews_count publication_date        publisher
# 0                   27591        9/16/2006  Scholastic Inc.
# 1                   29221         9/1/2004  Scholastic Inc.
# 2                     244        11/1/2003       Scholastic
# 3                   36325         5/1/2004  Scholastic Inc.
# 4                     164        9/13/2004       Scholastic
# ...                   ...              ...              ...
# 11118                  20       12/21/2004    Da Capo Press
# 11119                  56        12/1/1988    Penguin Books
# 11120                  95         8/1/1993    Penguin Books
# 11121                 139        2/27/2007             Ecco
# 11122                  12        5/28/2006    Edimat Libros
#
# [11123 rows x 12 columns]

# %%
books.loc[books["title"].str.contains("")]
# Out:
#        bookID                                                         title  \
# 0           1     Harry Potter and the Half-Blood Prince (Harry Potter  #6)
# 1           2  Harry Potter and the Order of the Phoenix (Harry Potter  #5)
# 2           4    Harry Potter and the Chamber of Secrets (Harry Potter  #2)
# 3           5   Harry Potter and the Prisoner of Azkaban (Harry Potter  #3)
# 4           8        Harry Potter Boxed Set  Books 1-5 (Harry Potter  #1-5)
# ...       ...                                                           ...
# 11118   45631              Expelled from Eden: A William T. Vollmann Reader
# 11119   45633                                   You Bright and Risen Angels
# 11120   45634                               The Ice-Shirt (Seven Dreams #1)
# 11121   45639                                                   Poor People
# 11122   45641                                   Las aventuras de Tom Sawyer
#
#                                                       authors  average_rating  \
# 0                                  J.K. Rowling/Mary GrandPré            4.57
# 1                                  J.K. Rowling/Mary GrandPré            4.49
# 2                                                J.K. Rowling            4.42
# 3                                  J.K. Rowling/Mary GrandPré            4.56
# 4                                  J.K. Rowling/Mary GrandPré            4.78
# ...                                                       ...             ...
# 11118  William T. Vollmann/Larry McCaffery/Michael Hemmingson            4.06
# 11119                                     William T. Vollmann            4.08
# 11120                                     William T. Vollmann            3.96
# 11121                                     William T. Vollmann            3.72
# 11122                                              Mark Twain            3.91
#
#              isbn         isbn13 language_code    num_pages  ratings_count  \
# 0      0439785960  9780439785969           eng          652        2095690
# 1      0439358078  9780439358071           eng          870        2153167
# 2      0439554896  9780439554893           eng          352           6333
# 3      043965548X  9780439655484           eng          435        2339585
# 4      0439682584  9780439682589           eng         2690          41428
# ...           ...            ...           ...          ...            ...
# 11118  1560254416  9781560254416           eng          512            156
# 11119  0140110879  9780140110876           eng          635            783
# 11120  0140131965  9780140131963           eng          415            820
# 11121  0060878827  9780060878825           eng          434            769
# 11122  8497646983  9788497646987           spa          272            113
#
#        text_reviews_count publication_date        publisher
# 0                   27591        9/16/2006  Scholastic Inc.
# 1                   29221         9/1/2004  Scholastic Inc.
# 2                     244        11/1/2003       Scholastic
# 3                   36325         5/1/2004  Scholastic Inc.
# 4                     164        9/13/2004       Scholastic
# ...                   ...              ...              ...
# 11118                  20       12/21/2004    Da Capo Press
# 11119                  56        12/1/1988    Penguin Books
# 11120                  95         8/1/1993    Penguin Books
# 11121                 139        2/27/2007             Ecco
# 11122                  12        5/28/2006    Edimat Libros
#
# [11123 rows x 12 columns]

# %%
movies = movies.drop(columns= ["poster","certificate","runtime","genre","about","director","stars","votes", "gross_earn"])

# %%
mini_movies = movies.head()

# %%
books = books.drop(columns= ["bookID", "authors" ,"isbn"	,"isbn13","ratings_count",	"text_reviews_count"	,"publication_date",	"publisher"])

# %%
books.drop(columns =["average_rating","language_code"] )
# Out:
#                                                               title  \
# 0         Harry Potter and the Half-Blood Prince (Harry Potter  #6)
# 1      Harry Potter and the Order of the Phoenix (Harry Potter  #5)
# 2        Harry Potter and the Chamber of Secrets (Harry Potter  #2)
# 3       Harry Potter and the Prisoner of Azkaban (Harry Potter  #3)
# 4            Harry Potter Boxed Set  Books 1-5 (Harry Potter  #1-5)
# ...                                                             ...
# 11118              Expelled from Eden: A William T. Vollmann Reader
# 11119                                   You Bright and Risen Angels
# 11120                               The Ice-Shirt (Seven Dreams #1)
# 11121                                                   Poor People
# 11122                                   Las aventuras de Tom Sawyer
#
#          num_pages
# 0              652
# 1              870
# 2              352
# 3              435
# 4             2690
# ...            ...
# 11118          512
# 11119          635
# 11120          415
# 11121          434
# 11122          272
#
# [11123 rows x 2 columns]

# %%
books.head()
# Out:
#                                                           title  \
# 0     Harry Potter and the Half-Blood Prince (Harry Potter  #6)
# 1  Harry Potter and the Order of the Phoenix (Harry Potter  #5)
# 2    Harry Potter and the Chamber of Secrets (Harry Potter  #2)
# 3   Harry Potter and the Prisoner of Azkaban (Harry Potter  #3)
# 4        Harry Potter Boxed Set  Books 1-5 (Harry Potter  #1-5)
#
#    average_rating language_code    num_pages
# 0            4.57           eng          652
# 1            4.49           eng          870
# 2            4.42           eng          352
# 3            4.56           eng          435
# 4            4.78           eng         2690

# %% [markdown]
# 1233,4242,4410,4111,4412,4413,8263,8873,10343,10344,10345,10346

# %%
hp_book = books.loc[books["title"].str.contains('Harry Potter')]
hp_book = hp_book.drop([613,615,1233,4242,4412,4410,4412,4413,8263,10343,10344,10345,10346,6,5,4,614,988,4411,4415,8873])
hp_book["rating"] =  hp_book["average_rating"] * 2

# %%
books["rating"] =  books["average_rating"] * 2

# %%
hp_book.drop(columns =["average_rating","language_code"] )
# Out:
#                                                               title  \
# 0         Harry Potter and the Half-Blood Prince (Harry Potter  #6)
# 1      Harry Potter and the Order of the Phoenix (Harry Potter  #5)
# 2        Harry Potter and the Chamber of Secrets (Harry Potter  #2)
# 3       Harry Potter and the Prisoner of Azkaban (Harry Potter  #3)
# 10674   Harry Potter and the Philosopher's Stone (Harry Potter  #1)
# 10675        Harry Potter and the Goblet of Fire (Harry Potter  #4)
#
#          num_pages  rating
# 0              652    9.14
# 1              870    8.98
# 2              352    8.84
# 3              435    9.12
# 10674          250    8.94
# 10675          636    9.12

# %%
hp_book
# Out:
#                                                               title  \
# 0         Harry Potter and the Half-Blood Prince (Harry Potter  #6)
# 1      Harry Potter and the Order of the Phoenix (Harry Potter  #5)
# 2        Harry Potter and the Chamber of Secrets (Harry Potter  #2)
# 3       Harry Potter and the Prisoner of Azkaban (Harry Potter  #3)
# 10674   Harry Potter and the Philosopher's Stone (Harry Potter  #1)
# 10675        Harry Potter and the Goblet of Fire (Harry Potter  #4)
#
#        average_rating language_code    num_pages  rating
# 0                4.57           eng          652    9.14
# 1                4.49           eng          870    8.98
# 2                4.42           eng          352    8.84
# 3                4.56           eng          435    9.12
# 10674            4.47           gla          250    8.94
# 10675            4.56           eng          636    9.12

# %%
hp_movies = movies.loc[movies["title"].str.startswith("Harry Potter")]
hp_movies = hp_movies.drop([261,87])
hp_movies
# Out:
#                                          title  rating
# 151   Harry Potter and the Philosopher's Stone     7.6
# 197    Harry Potter and the Chamber of Secrets     7.4
# 201        Harry Potter and the Goblet of Fire     7.7
# 207   Harry Potter and the Prisoner of Azkaban     7.9
# 230  Harry Potter and the Order of the Phoenix     7.5
# 273     Harry Potter and the Half-Blood Prince     7.6

# %%
jurassic_book = books.loc[books["title"].str.contains('Jurassic Park')]
jurassic_book = jurassic_book.drop([2130,5866])
jurassic_book = jurassic_book.drop([4752])
jurassic_book
# Out:
#               title  average_rating language_code    num_pages  rating
# 5867  Jurassic Park            4.02         en-US          400    8.04

# %%
dune_book = books.loc[books["title"].str.startswith('Dune')]
dune_book = dune_book.drop(67)
dune_book
# Out:
#                 title  average_rating language_code    num_pages  rating
# 10433  Dune (Dune #1)            4.22           spa          702    8.44

# %% [markdown]
# Jrassic park,
# harry potter,
# dune, the hunger games , the godfather, sherlock holmes, narnia

# %%
GF_book = books.loc[books["title"].str.contains("The Godfather")]
GF_book
# Out:
#               title  average_rating language_code    num_pages  rating
# 5855  The Godfather            4.37           eng          448    8.74

# %%
pd.set_option('display.max_colwidth', None)

# %%
narnia_book = books.loc[books["title"].str.contains("Narnia")]
narnia_book = narnia_book.drop([3017,3018,4832,9491,11110,9490])
narnia_book
# Out:
#                                                                 title  \
# 5012  The Voyage of the “Dawn Treader” (The Chronicles of Narnia  #3)
# 7521                        Prince Caspian (Chronicles of Narnia  #4)
# 9489  The Lion  the Witch and the Wardrobe (Chronicles of Narnia  #1)
#
#       average_rating language_code    num_pages  rating
# 5012            4.09           eng          216    8.18
# 7521            3.97           eng          223    7.94
# 9489            4.25           eng           48    8.50

# %%
narnia_movie = movies.loc[movies["title"].str.contains("Narnia")]

# %%
GF_movie = movies.loc[movies["title"].str.contains("The Godfather")]
GF_movie = GF_movie.drop([32,385])

# %%
dune_movie = movies.loc[movies["title"].str.contains("dune")]

# %%
jurassic_movie = movies.loc[movies["title"].str.contains('Jurassic Park')]
jurassic_movie = jurassic_movie.drop([352,507])

# %%
x_axis = np.arange(len(jurassic_movie["title"]))
x_axis2 = np.arange(len(jurassic_book["title"]))

# %%
plt.figure(1, figsize=(6, 7))
title = "jurassic park book"
plt.bar(x_axis -0.06,jurassic_movie["rating"],width= 0.1,label = 'jurassic park movie',color = "g")
plt.bar(x_axis2 +0.06,jurassic_book["rating"],width =0.1,label = "jurassic park book", color = "y")
plt.ylim(0,10.0)
plt.legend()  
plt.show()
