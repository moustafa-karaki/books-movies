# %%
import pandas as pd
import numpy as np
import os

# %%
movies = pd.read_csv('movies.csv')

# %%
movies.head()
# Out:
#                                               poster  \
# 0  https://m.media-amazon.com/images/S/sash/4Fyxw...
# 1  https://m.media-amazon.com/images/S/sash/4Fyxw...
# 2  https://m.media-amazon.com/images/S/sash/4Fyxw...
# 3  https://m.media-amazon.com/images/S/sash/4Fyxw...
# 4  https://m.media-amazon.com/images/S/sash/4Fyxw...
#
#                       title certificate  runtime                      genre  \
# 0  The Shawshank Redemption          15  142 min                      Drama
# 1           The Dark Knight         12A  152 min       Action, Crime, Drama
# 2                 Inception         12A  148 min  Action, Adventure, Sci-Fi
# 3                Fight Club          18  139 min                      Drama
# 4              Pulp Fiction          18  154 min               Crime, Drama
#
#    rating                                              about  \
# 0     9.3  Two imprisoned men bond over a number of years...
# 1     9.0  When the menace known as the Joker wreaks havo...
# ...

# %%
movies.loc[movies["title"].str.startswith('Harry Potter')]
# Out:
#                                                 poster  \
# 87   https://m.media-amazon.com/images/S/sash/4Fyxw...
# 151  https://m.media-amazon.com/images/S/sash/4Fyxw...
# 197  https://m.media-amazon.com/images/S/sash/4Fyxw...
# 201  https://m.media-amazon.com/images/S/sash/4Fyxw...
# 207  https://m.media-amazon.com/images/S/sash/4Fyxw...
# 230  https://m.media-amazon.com/images/S/sash/4Fyxw...
# 261  https://m.media-amazon.com/images/S/sash/4Fyxw...
# 273  https://m.media-amazon.com/images/S/sash/4Fyxw...
#
#                                             title certificate  runtime  \
# 87   Harry Potter and the Deathly Hallows: Part 2         12A  130 min
# 151      Harry Potter and the Philosopher's Stone          PG  152 min
# 197       Harry Potter and the Chamber of Secrets          PG  161 min
# 201           Harry Potter and the Goblet of Fire         12A  157 min
# 207      Harry Potter and the Prisoner of Azkaban          PG  142 min
# ...
